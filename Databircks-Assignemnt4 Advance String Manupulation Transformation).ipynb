# %%
df=spark.read.csv("/Volumes/workspace/default/demo/EmployeeData-.csv",header=True)
df.display()

# %% [markdown]
# <b> What is the abbreviated version of each employee's last name, with the first letter and the two following letters included?

# %%
# Write your code using the Spark Function
from pyspark.sql.functions import col,substring
df1=df.withColumn('AbbreviatedColumn',substring(col('last_name'),1,3))
df1.display()

# %% [markdown]
# d
# <b> What is the domain name of each employee's email address, so that their emails can be filtered and routed to the correct department?

# %%
# Write your code using the Spark Function
from pyspark.sql.functions import split
df2 = df.select("email", split(col("email"), "@").getItem(1).alias("email_user"))
df2.display()

# %% [markdown]
# d
# <b> In an effort to protect their privacy, what is each employee's name spelled backwards?

# %%
# Write your code using the Spark Function
from pyspark.sql.functions import col, reverse

df2 = df.select(
    "first_name",
    reverse(col("first_name")).alias("name_backwards")
)
display(df2)

# %% [markdown]
# d
# <b> In order to make their email addresses harder to guess, what is each employee's email address spelled backwards?

# %%
# Write your code using the Spark Function
from pyspark.sql.functions import reverse,col

df5=df.withColumn('Emailback',reverse(col('email')))
df5.display()

# %% [markdown]
# d
# <b> What is each employee's first name, repeated twice, to improve personalization of emails and messages?

# %%
from pyspark.sql.functions import col, concat_ws

df_out = df.select(
    col("first_name"),
    concat_ws(" ", col("first_name"), col("first_name")).alias("first_name_twice")
)
display(df_out)

# %% [markdown]
# d
# <b> What is the country code of each employee's email domain, which can help identify global market opportunities?

# %%
from pyspark.sql.functions import col, lower, split

df2 = df.select(
    "email",
    lower(split(split(col("email"), "@").getItem(1), r"\.").getItem(1)).alias("country_code")
)

display(df2)

# %% [markdown]
# d
# <b> What is the position of the first occurrence of a dot ('.') character in each employee's email address, which can be used to standardize email addresses in a database?

# %%
# Write your code using the Spark Function
from pyspark.sql.functions import col, instr

df2 = df.select(
    "email",
    instr(col("email"), ".").alias("first_dot_pos")
)

display(df2)

# %% [markdown]
# d
# <b> What is the full name and email address of each employee, concatenated with a space separator, for use in email communication?

# %%
# Write your code using the Spark Function
from pyspark.sql.functions import concat_ws
df8=df.withColumn('Fullnameeamil',concat_ws(' ',col('first_name'),col('email')))
df8.display()

# %% [markdown]
# d
# <b> What is the first letter of each employee's first name in uppercase, followed by the rest of the name in lowercase, to ensure consistency and proper capitalization?

# %%
# Write your code using the Spark Function
from pyspark.sql.functions import col, concat_ws,substring,upper,concat,lower

df9 =df.withColumn('Capitalization',concat(upper(substring(col('first_name'),1,1)),lower(col('last_name')))
                   )
display(df9)
